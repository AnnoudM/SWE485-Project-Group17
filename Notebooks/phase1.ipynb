# %% [markdown]
# ### **1. General Information**

# %% [markdown]
# ### **1.1 Number of Observations and Variables**

# %%
import pandas as pd

file_path = "../Dataset/Averages in in General Aptitude Tests aa.csv"
df = pd.read_csv(file_path)

rows, columns = df.shape
print(f"Number of observations (rows): {rows}")
print(f"Number of variables (columns): {columns}")
# Out:
# Number of observations (rows): 6720
# Number of variables (columns): 11

# %% [markdown]
# ### **1.2 Types of Variables**

# %%
print(df.dtypes)
# Out:
# اسم_المدرسة                         object
# المنطقة_الإدارية                    object
# الإدارة_التعليمية                   object
# المكتب_التعليمي                     object
# السلطة                              object
# نوع_التعليم                         object
# الجنس                               object
# نوع_الاختبار                        object
# تخصص_الاختبار                       object
# متوسط_أداء_الطلبة_في_المدرسة       float64
# ترتيب_المدرسة_على_مستوى_المدارس      int64
# dtype: object

# %% [markdown]
# ### **1.3 Names of Variables**

# %%
print(df.columns.tolist())
# Out:
# ['اسم_المدرسة', 'المنطقة_الإدارية', 'الإدارة_التعليمية', 'المكتب_التعليمي', 'السلطة', 'نوع_التعليم', 'الجنس', 'نوع_الاختبار', 'تخصص_الاختبار', 'متوسط_أداء_الطلبة_في_المدرسة', 'ترتيب_المدرسة_على_مستوى_المدارس']

# %% [markdown]
# ### **4. Summary of the Dataset**
#
# In this section, I will provide sample records from the original dataset to give an overview of its structure and content and the visualizations showing the distribution of variables, missing values, and statistical summaries.

# %% [markdown]
# ### **4.1 Samples of the raw dataset**

# %%
import pandas as pd

# First we will download the dataset
file_path = "../Dataset/Averages in in General Aptitude Tests aa.csv"  
df = pd.read_csv(file_path)

# After downloading, we will now display some samples from the dataset
df.sample(10)
# Out:
#                                           اسم_المدرسة المنطقة_الإدارية  \
# 5615                       ثانوية المنتزه نظام مقررات             حائل
# 4301                                    ثانوية الصديق             حائل
# 3594    الثانوية الأولى بقبه - مقررات بمحافظة الاسياح           القصيم
# 2774                 الثانوية الثانية بالمهد - مقررات  المدينة المنورة
# 2985                         ثانوية النجامية - مقررات            جازان
# 1198  ثانوية الأبناء بالأسطول الشرقي بالجبيل - مقررات          الشرقية
# 6285                حذيفة بن اليمان الثانوية - مقررات      مكة المكرمة
# 5768                     مجمع الصديق الثانوي - مقررات      مكة المكرمة
# 6266                        ثانوية ابن زيدون - مقررات           القصيم
# 640         الثانوية الحادية والستون بجدة نظام مقررات      مكة المكرمة
#
#                             الإدارة_التعليمية                 المكتب_التعليمي  \
# 5615       الإدارة العامة للتعليم بمنطقة حائل            مكتب التعليم بالشمال
# ...

# %% [markdown]
# ### **4.2 Distribution of Scores**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['متوسط_أداء_الطلبة_في_المدرسة'], bins=20, kde=True)
plt.title('توزيع درجات الطلاب')
plt.xlabel('متوسط الدرجة')
plt.ylabel('عدد الطلاب')
plt.show()

# %% [markdown]
# ### **4.3 Distribution of Schools by Administrative Region**

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='المنطقة_الإدارية', data=df, order=df['المنطقة_الإدارية'].value_counts().index)
plt.title('توزيع المدارس حسب المنطقة الإدارية')
plt.xlabel('عدد المدارس')
plt.ylabel('المنطقة الإدارية')
plt.show()

# %% [markdown]
# ### **4.4 Distribution of Schools by Type of Education**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='نوع_التعليم', data=df)
plt.title('توزيع المدارس حسب نوع التعليم')
plt.xlabel('نوع التعليم')
plt.ylabel('عدد المدارس')
plt.show()

# %% [markdown]
# ### **4.5 Distribution of Schools by Gender (Boys/Girls)**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='الجنس', data=df)
plt.title('توزيع المدارس حسب الجنس')
plt.xlabel('الجنس')
plt.ylabel('عدد المدارس')
plt.show()

# %% [markdown]
# ### **4.6 Distribution of Schools by Test Specialization**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='تخصص_الاختبار', data=df)
plt.title('توزيع المدارس حسب تخصص الاختبار')
plt.xlabel('تخصص الاختبار')
plt.ylabel('عدد المدارس')
plt.show()

# %% [markdown]
# ### **4.7 Missing values visualization**

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('خريطة القيم المفقودة')
plt.show()

# %% [markdown]
# **The heatmap indicates that there are no missing values or the missing values are very minimal. The dark purple color represents complete data with no missing entries.**

# %% [markdown]
# ### **4.8 statistical summaries(mean and variance)**
#  I selected 'متوسط أداء الطلبة في المدرسة' because it is numerical column.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a statistical summary
stats = df[['متوسط_أداء_الطلبة_في_المدرسة']].describe()

plt.figure(figsize=(8, 4))
plt.axis('off')  
table = plt.table(cellText=stats.values, colLabels=stats.columns, rowLabels=stats.index, loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)
plt.title('Statistical Summary of Students\' Performance')
plt.show()

# %%
import numpy as np

# Calculate the mean and standard deviation
mean_value = df['متوسط_أداء_الطلبة_في_المدرسة'].mean()
std_value = df['متوسط_أداء_الطلبة_في_المدرسة'].std()

plt.figure(figsize=(8, 6))
plt.bar(['Mean', 'Standard Deviation'], [mean_value, std_value], color=['skyblue', 'salmon'])
plt.title('Mean and Standard Deviation of Students\' Performance')
plt.ylabel('Value')
plt.show()

# %%
# Variance calculation
variance_value = df['متوسط_أداء_الطلبة_في_المدرسة'].var()

plt.figure(figsize=(6, 4))
plt.bar(['Variance'], [variance_value], color='orange')
plt.title('Variance of Students\' Performance')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ### **5. Data Preprocessing**

# %% [markdown]
# ### **Step 1: Load the Data and Check for Missing Values**
# Before cleaning or analyzing the data, We need to understand its structure. This helps us see:
# - How many rows and columns are in the dataset.
# - What types of data are in each column.
# - If there are any missing values that need to be handled.

# %%
import pandas as pd

# First, We need to load the data to understand its structure and check for any issues.
file_path = "../Dataset/Averages in in General Aptitude Tests aa.csv" 
df = pd.read_csv(file_path)  # Use read_csv to load the dataset from the file
df_original = pd.read_csv(file_path)

# We use df.info() to see the number of rows and columns, and the data types for each column
df.info()  

# Here, We calculate the number of missing values in each column to check for any incomplete data
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)  # Print the result to identify columns with missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6720 entries, 0 to 6719
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   اسم_المدرسة                      6720 non-null   object
#  1   المنطقة_الإدارية                 6720 non-null   object
#  2   الإدارة_التعليمية                6707 non-null   object
#  3   المكتب_التعليمي                  6706 non-null   object
#  4   السلطة                           6720 non-null   object
#  5   نوع_التعليم                      6720 non-null   object
#  6   الجنس                            6720 non-null   object
#  7   نوع_الاختبار                     6720 non-null   object
#  8   تخصص_الاختبار                    6720 non-null   object
#  9   متوسط_أداء_الطلبة_في_المدرسة     6720 non-null   float64
#  10  ترتيب_المدرسة_على_مستوى_المدارس  6720 non-null   int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 577.6+ KB
# ...

# %% [markdown]
# #### What We Found:
# - The dataset has 6,720 rows and 11 columns.
# - Most columns have no missing values, but:
#   - **"الإدارة_التعليمية"** is missing 13 values.
#   - **"المكتب_التعليمي"** is missing 14 values.
#
# Since these columns have missing values, We will now remove the rows where data is missing to keep our dataset clean.

# %% [markdown]
# ### **Step 2: Remove Rows with Missing Values**
#
# Since we found missing values in the previous step, We decided to remove those rows instead of filling them with default values. This way, our dataset only contains complete information, which is better for analysis and machine learning models.

# %%
# Now we will remove all rows that have any missing values
df_cleaned = df.dropna()  # dropna() removes any row that contains a missing value

# After removing, We need to check if there are still any missing values
print("Missing Values After Removal:\n", df_cleaned.isnull().sum())

# Also, We will check the number of rows left after removing missing values
print(f"Number of rows before cleaning: {df.shape[0]}")
print(f"Number of rows after cleaning: {df_cleaned.shape[0]}")
# Out:
# Missing Values After Removal:
#  اسم_المدرسة                        0
# المنطقة_الإدارية                   0
# الإدارة_التعليمية                  0
# المكتب_التعليمي                    0
# السلطة                             0
# نوع_التعليم                        0
# الجنس                              0
# نوع_الاختبار                       0
# تخصص_الاختبار                      0
# متوسط_أداء_الطلبة_في_المدرسة       0
# ترتيب_المدرسة_على_مستوى_المدارس    0
# dtype: int64
# Number of rows before cleaning: 6720
# Number of rows after cleaning: 6706

# %% [markdown]
# #### What We Did:
# - Used `df.dropna()` to remove all rows with missing values.
# - Checked again if there are any missing values left.
# - Compared the number of rows before and after cleaning to see how many rows were removed.

# %% [markdown]
# ### **Step 3: Check for Duplicate Rows**
# Duplicate rows can cause issues in data analysis and machine learning. If the same data appears multiple times, it can make certain patterns seem more important than they actually are, leading to bias in predictions.

# %%
# First, We will check if there are any duplicate rows in the dataset
duplicate_count = df_cleaned.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### What We Found:
# - We used `df_cleaned.duplicated().sum()` to check for duplicate rows.
# - The result was **0**, meaning there are no duplicate rows in the dataset.
# - Since no duplicates were found, We didn't need to remove any rows.

# %% [markdown]
# ### **Step 4: Remove Column "نوع_الاختبار"**
#
# After analyzing the column نوع_الاختبار, we found that all the values are the same (قدرات). This means the column doesn't add any useful information for the analysis or model building.
# Keeping it would only add unnecessary noise, so we decided to remove it.

# %%
# Remove the "نوع_الاختبار" column as it contains only one unique value
df_cleaned = df_cleaned.drop(columns=["نوع_الاختبار"])

# Check the first few rows to confirm the column is removed
df_cleaned.head()
# Out:
#                                         اسم_المدرسة المنطقة_الإدارية  \
# 0               أم سلمة الثانوية للموهوبات - مقررات      مكة المكرمة
# 1       ثانوية الرواد الأهلية ( الازدهار ) - مقررات           الرياض
# 2                  ثانوية الموهوبات ( نظام مقررات )      مكة المكرمة
# 3  الثانوية السادسة لتحفيظ القرآن الكريم 6 - مقررات           الرياض
# 4             ثانوية مدارس الظهران الاهلية (مقررات)          الشرقية
#
#                            الإدارة_التعليمية                المكتب_التعليمي  \
# 0  الإدارة العامة للتعليم بمنطقة مكة المكرمة  مكتب التعليم جنوب مكة المكرمة
# 1       الإدارة العامة للتعليم بمنطقة الرياض                           شمال
# 2         الإدارة العامة للتعليم بمحافظة جدة         مكتب التعليم بشمال جدة
# 3       الإدارة العامة للتعليم بمنطقة الرياض                           شمال
# 4    الإدارة العامة للتعليم بالمنطقة الشرقية     مكتب التعليم بمحافظة الخبر
#
#   السلطة     نوع_التعليم الجنس تخصص_الاختبار  متوسط_أداء_الطلبة_في_المدرسة  \
# ...

# %% [markdown]
# ***Why we removed it?***
#
# The column نوع_الاختبار contains the same value (قدرات) for all rows.
#
# Columns with no variation don’t help in making predictions or analyzing the data.
#
# ***How we removed it?***
#
# We used the .drop() function to delete the column.
#
# After dropping it, we confirmed the column was removed by checking the dataset.

# %% [markdown]
# ### **Step 5: Visualizing Relationships in the Data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(data=df_original, x="المنطقة_الإدارية", y="متوسط_أداء_الطلبة_في_المدرسة", errorbar=None)

plt.title("Average Student Performance by Region", fontsize=16)
plt.xlabel("Region", fontsize=14)
plt.ylabel("Average Student Performance", fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Why did we choose this?***
#
# Parents often prefer specific regions for their children’s education.
# If certain regions have consistently better schools, parents may choose to live in or send their kids to schools in those areas.
#
# ***What do we expect to see?***
#
# If some regions have higher student performance, parents may prioritize those areas for better education quality.
# If performance is similar across all regions, location might not matter as much.

# %%
plt.figure(figsize=(19, 8))
sns.barplot(data=df_original, x="نوع_التعليم", y="متوسط_أداء_الطلبة_في_المدرسة", errorbar=None)

plt.title("Average Performance by Type of School", fontsize=16)
plt.xlabel("Type of School", fontsize=14)
plt.ylabel("Average Student Performance", fontsize=14)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ***Why did we choose this?***
#
# Parents may wonder whether private schools perform better than public schools.
# If private schools have significantly higher performance, parents might prefer them despite higher costs.
#
# ***What do we expect to see?***
#
# If private schools outperform public schools, parents may prefer them for better education.
# If there’s no major difference, parents may prioritize other factors like location or cost.

# %%
plt.figure(figsize=(38, 15))
sns.barplot(data=df_original, x="الإدارة_التعليمية", y="متوسط_أداء_الطلبة_في_المدرسة", errorbar=None)

plt.title("Average Performance by Educational District", fontsize=16)
plt.xlabel("Educational District", fontsize=14)
plt.ylabel("Average Student Performance", fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Why did we choose this?***
#
# Some educational districts (الإدارة التعليمية) might provide better quality education than others.
# This helps parents choose the best district for their children’s education.
#
# ***What do we expect to see?***
#
# Some districts might consistently have higher student performance, meaning they have better educational systems.
# If performance is similar across districts, then other factors might matter more.

# %% [markdown]
# ### **Step 6: Convert Categorical Data to Numbers**
# Machine learning models only work with numerical data, but our dataset has many text-based columns. To use these columns, we need to convert them into numbers.

# %%
from sklearn.preprocessing import LabelEncoder

categorical_columns = [
    "اسم_المدرسة", 
    "المنطقة_الإدارية", 
    "الإدارة_التعليمية", 
    "المكتب_التعليمي", 
    "السلطة", 
    "نوع_التعليم", 
    "الجنس", 
    "تخصص_الاختبار"
]

label_encoders = {}  
for col in categorical_columns:
    le = LabelEncoder()
    df_cleaned.loc[:, col] = le.fit_transform(df_cleaned[col])  
    label_encoders[col] = le  

df_cleaned.head()
# Out:
#   اسم_المدرسة المنطقة_الإدارية الإدارة_التعليمية المكتب_التعليمي السلطة  \
# 0          28               11                45             294      3
# 1        2496                3                38              71      0
# 2        3050               11                34             218      3
# 3        1276                3                38              71      3
# 4        3938                4                31             245      0
#
#   نوع_التعليم الجنس تخصص_الاختبار  متوسط_أداء_الطلبة_في_المدرسة  \
# 0           6     0             0                     89.622377
# 1           6     0             1                     84.440000
# 2           6     0             0                     89.280423
# 3           0     0             1                     83.550000
# 4           6     0             0                     88.903225
#
#    ترتيب_المدرسة_على_مستوى_المدارس
# 0                                1
# 1                                1
# 2                                2
# ...

# %% [markdown]
# ### What We Did:
#
# We selected the categorical columns manually, like المنطقة_الإدارية, نوع_التعليم, الإدارة_التعليمية, and الجنس, because they are text-based.
#
# Then, we used Label Encoding to change the text into numbers so the model can understand them.
#
# We saved the encoders in case we need to change the numbers back to text later or use them for other data.
#
# Finally, we checked the dataset, and now all the text columns are successfully turned into numbers.

# %% [markdown]
# ### **Step 7: Normalize the Numerical Data**
# Some numerical columns might have very different ranges, which can cause problems for machine learning models. For example, one column might have values like 1, 2, 3, while another has values like 1000, 2000, 3000. If we normalize the data, all columns will be scaled between 0 and 1, making it easier for the model to learn.

# %%
from sklearn.preprocessing import MinMaxScaler

columns_to_scale = ["متوسط_أداء_الطلبة_في_المدرسة"] 

scaler = MinMaxScaler()  

df_cleaned = df_cleaned.copy()  

df_cleaned.loc[:, columns_to_scale] = scaler.fit_transform(df_cleaned[columns_to_scale]).astype("float64")

df_cleaned.head()
# Out:
#   اسم_المدرسة المنطقة_الإدارية الإدارة_التعليمية المكتب_التعليمي السلطة  \
# 0          28               11                45             294      3
# 1        2496                3                38              71      0
# 2        3050               11                34             218      3
# 3        1276                3                38              71      3
# 4        3938                4                31             245      0
#
#   نوع_التعليم الجنس تخصص_الاختبار  متوسط_أداء_الطلبة_في_المدرسة  \
# 0           6     0             0                      1.000000
# 1           6     0             1                      0.872710
# 2           6     0             0                      0.991601
# 3           0     0             1                      0.850850
# 4           6     0             0                      0.982336
#
#    ترتيب_المدرسة_على_مستوى_المدارس
# 0                                1
# 1                                1
# 2                                2
# ...

# %% [markdown]
# #### What We Did:
# We selected the column متوسط_أداء_الطلبة_في_المدرسة because it has continuous numerical values (student performance). We needed to scale it to a range between 0 and 1 so that it’s easier for the model to process.
#
# We used MinMaxScaler to do the normalization. This is important because some models work better when all the data is on the same scale. Without this, big numbers could affect the results too much compared to smaller ones.
#
# We checked the dataset after scaling to make sure only this column was changed, and that other columns, like rankings or text-based ones, stayed the same.

# %% [markdown]
# ### **Step 8: Check if we need to Apply Data Transformation**
# Transformation is needed when:
# 1. The data is not normally distributed (skewed).
# 2. The data has extreme outliers that can affect model performance.
# 3. The model requires log or power transformations to handle skewed data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


for col in numerical_columns:
    plt.figure(figsize=(10, 6))  
    sns.histplot(df_cleaned[col], kde=True, bins=30)  
    plt.title(f"Distribution of {col}", fontsize=14) 
    plt.xlabel(col, fontsize=12)  # Add x-axis label
    plt.ylabel("Frequency", fontsize=12)  
    plt.xticks(rotation=45)  
    plt.show()

# %% [markdown]
# #### What We Found:
# - After plotting the distributions of all numerical columns, We observed that:
#   - Most of the distributions are already well balanced or only slightly skewed.
#   - There are no extreme outliers that require transformation.
#   - The dataset is already normalized (values between 0 and 1), meaning no additional scaling is required.
#
# - Since the numerical features are already in a good range and well distributed, transformation is not necessary.

# %% [markdown]
# ### **Step 9: Save the Cleaned Dataset**

# %%
output_file_path = "../Dataset/Cleaned_Averages.csv"  
df_cleaned.to_csv(output_file_path, index=False)  

print(f" Cleaned dataset has been saved successfully to {output_file_path}")
# Out:
#  Cleaned dataset has been saved successfully to ../Dataset/Cleaned_Averages.csv
